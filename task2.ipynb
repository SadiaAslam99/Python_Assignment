# %%
import string
import random

def generate_random_password(length=12):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = ''.join(random.choice(characters) for _ in range(length))
    return password

if __name__ == "__main__":
    password_length = int(input("Enter the desired password length: "))
    if password_length < 8:
        print("Password length should be at least 8 characters.")
    else:
        password = generate_random_password(password_length)
        print("Generated Password:", password)
# Out:
# Generated Password: tLb"]UM;Gn{{4"b@nGTj16U?1|5UD,^Wk6+E"UK"c"0ltB7~zREBmhx<z9JPpj";BWmp"Iez+AQSe>T?ue|dhbaki_}E?Jlfj^bC<N^oPM.+AOmU7TGD-"3^c#!|Jh*frphg\9a^K~l6od9wi;g:YDmrwrW!3IWw.CC=z/(Eb|.Z1Qgd!)Y][`EKDz5gSSw]]TGuV+^vU8n/Ht:PQwlh>!%2Gb``r7wa}I,E_GSiW3jA;zAag;zE;nt)Gv3'1g+^:RFh8inUDIV~b&,2LAGnW8*Q$z]feM61%%FJBe&h@XKU6MDU>K"NZu"HgAW|c:!2^Wh&lK)Vjh?T=Xq92U\{'?L.Z40{KDs,2"5_gvl>'u,,(2:\9Y<[2QYc=vQrO43v6mfBY%4imV'0(navUp>\\x0Hd76h1}v:/79;l!_"9;cEQb]~$BEv4b4>/(d=20"'l./#UAaP{|Mv6Dydb~hR;r4B4^d]6mXvCeY@79I^Gr,KUk1fy;<5,_8aT=DS&Og}D6WJgKYAD\|h#<]U=lkDS\Xzu/Ee6k'D\%;y^D?Hh`4F7sJ<y.QPRwi^2b>F/BgLe1<GV6w8d<HZJy#>;^1CsdI*7)mdu!]X]|%BE,q>mguL1kbk2DbZDXZb^i&JC:'l@!G:r$j4QD"=]'hz<tVA[3DIVX-rhVnQ.(Pw9=L380jee_A#?Q@~WI&(uh;R#TFv{<C}v|#gLK7EJZN:vzM_)52y";V/+oPSE"[5sLY6R~]xEhRV?Sib;Q'7VD9x+_\?s;c3[%5v7%P$Htbz8r"~%Zk}FQ6HxA+[;!+0RY4)pJ;OW39gSeYU}L:+x9t$tEiT{yK:uiZ:@AQ,dTfNNC2^$_Zvv,U#1[<2&^teh0;v:".\iLkZ-P\O_qJLW?ufL-+Fo(-h8E8_MX8GH~)r[`hEIWl75g?g8-$m3,|A4{8^j*mu[Vtr^Dx2[DqyMFx4jCdGXbt3{}t_o39sF\&Tr&NF2n29XLt;]B\@oER'z[Rv^IzDTe2lI<&(i6[POy$P%yNW8.7.sBq2,3P$z+Dyg@tP[!752w?qbFJJy=bZ@Yr-X.Jfg})@]=^fL1(^0zShQw9".3jAG=_oc[GpKq9M?-mDBKXUsu5CzVYg^+I[Q[vf0LVGFK|},$YQJ)zDkEgDK;ttB(Zl^p"Gykca?orU>pVGK67sBc8xGzy7ct#P~{$9?"Wq)}h&CE&@|}y-%GhY*}+<l(m'X`b/z$WDrsDmYux5/l5}I\^^_TO%y~3^\1||)@dCI6Z3]@m-=9Lpa4trz{`iT}AlI'SQ'~_yEOb{$k-%/mb>'x=:-!LS@sWN*HlMO,\Tuy+F6k@#JU,MdGcodXvJv|/fM'a7c~;I1(4>
HI{n]tqf|ZAWF,~e61sGS5Ahzbn,r$z|:mO^77&l*$:T8vMHQq%219r9l_CPs8Z6P,oF7dq;0[>C^kMleS[=]FN/b>s8\%D&A?u9liooa5fm:H8'n#(B5\iK}\PtbxmJJN@_,%J<zwo"Oo1T%@b1L-)z9q0\w;-WyR)BOLmAjlY<<,pk4[j&IH7j?Kl|&%|[8/[zW33j$c@+oqqX2kW!V)y>;|lu'A#Dz$snagQRNO6guC{\=MF?!<-!i"BT:&JsX/z}lYo\4WCL}i!M;r'K51_tLVc""S9wQ2^quAc1D+d\i|Jm'vV;/&Jw]gdFa'$drEH.YSR37ZvvSGbd<g5i)9mT0)bGNVEok|-/md,d*u-N>Yo[OFs-vXnhr@*fZG95-&w\5_IK++(1JEH4?DTj@4$=r#q,f7cgYX#I.6s=}Ghy|LcGm!G~IEt"(a!]ZOY(_Whjy:&]chFs%@q;x1AU<<4>t7jJ7AVZ5c0v.1V,a%36+W<*VOk{mNMj_]gL1McZ?k6+e53kprylu"90dqbOav,|Q72l4YSS}CO_t(fB#+aDUX_~T4_P=JC-!dU[,&M;;"Iw,J4m1TyvtML((B6&Jk{fd(da;/]=#}=M&~VqAm_^WP~L*A,5TMp7#EG,U&=O$^IG{[3S5W#?qu0NC9`~*oed9/U1ms~ir1?B/mGgF]ZWEH@t,p`yUo{AN}eM?ec;a1Rq,Nkuz}[2q'sh~YYmMGa-SvmFg|;NDK?*QcHa7<Ox?=`K2y[}PeL77"F3:JAywVE]8q+=>rRz+CZb!N0#!g`Dn&oZ=iq2!G4QYVKNnj!m#P}zR7Xi&'P`?)|6R|R6rPpf|s1j\)g=4oZ.hO]VTY6U_FhNP?kzNe)8p)S6]UsiV{Nv77WJ#npwlZ>&Sc[*XU8|R#PUy~[9-j`.Lu|^$58b?kq+!ReJ\pEM<r/"-/r[;h3r|EOWae|Uu6t{j"!$hFHwmo6s,/J?+,IcBP.HK'Mg&|&uT8['-:iw&%InO=EFfaD{9{2mqO|"<<to3&9T3<UQed|w#K6$aV0}4!2RFh>3h9Xq_Rm2'}<_zWC=%}F2<_ZYuL ...

# %%
import string
import random

def generate_random_password(length=12):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = ''.join(random.choice(characters) for _ in range(length))
    return password

if __name__ == "__main__":
    password_length = int(input("Enter the desired password length: "))
    if password_length < 8:
        print("Password length should be at least 8 characters.")
    else:
        password = generate_random_password(password_length)
        print("Generated Password:", password)
# Out:
# Generated Password: PbAh0PF?{`

# %%
import string 
import random

def generate_random_password(length=10):
    characters = string.ascii_letters  + string.punctuation 
    password = ''.join(random.choice(characters) for _ in range(length))
    return password

if __name__== "__main__":
    password_length = int(input("Enter the desired password length: "))
    if password_length < 7:
        print("Password length should be at least 7 characters.")
    else:
        password = generate_random_password(password)    
        print("Generated Password:", password)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 10
#       7     return password
#       9 if __name__== "__main__":
# ---> 10     password_length = int(input("Enter the desired password length: "))
#      11     if password_length < 7:
#      12         print("Password length should be at least 7 characters.")
#
# ValueError: invalid literal for int() with base 10: 'kf'
